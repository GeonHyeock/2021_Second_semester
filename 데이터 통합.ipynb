# %%
import numpy as np
import pandas as pd
import pickle

# %%
with open("/Users/heogeonhyeock/Desktop/인빅_프로젝트/FC_order_distance_trafic_end22.pickle","rb") as fr:
    Trafic = pickle.load(fr)
Trafic = Trafic[["송화 -> 터미널","터미널 -> 수화"]]
Trafic
# Out:
#         송화 -> 터미널 터미널 -> 수화
# 1          514547      5390
# 2          514547      5390
# 3          514547    513833
# 4          514547    513833
# 5          514547    513833
# ...           ...       ...
# 1786343    528659    402678
# 1786347    528659    402678
# 1786348        제주        제주
# 1786349    302624     75620
# 1786354    402678      4940
#
# [1585447 rows x 2 columns]

# %%
with open("/Users/heogeonhyeock/Desktop/인빅_프로젝트/FC_order_distance2.pickle","rb") as fr:
    Distance = pickle.load(fr)
Distance = Distance[["distance_송화","distance_수화","distance"]]
Distance
# Out:
#         distance_송화 distance_수화 distance
# 1           14.3362     270.613  284.949
# 2           14.3362     294.613  308.949
# 3           14.3362      32.841  47.1772
# 4           14.3362     64.2811  78.6173
# 5           14.3362     64.2811  78.6173
# ...             ...         ...      ...
# 1786343     14.3362     41.4585  55.7948
# 1786347     14.3362     28.4156  42.7518
# 1786348     14.3362     432.125  446.461
# 1786349     14.3362     106.525  120.861
# 1786354     14.3362     290.217  304.554
#
# [1496444 rows x 3 columns]

# %%
with open("/Users/heogeonhyeock/Desktop/인빅_프로젝트/FC주문/FC_order.pickle","rb") as fr:
    FC_order = pickle.load(fr).reset_index(drop=True)
FC_order
# Out:
#         CORP_ID        REF_ORD_NO             BKG_NO  BKG_TYP  BKG_DATE  \
# 0         KX007  2021030365922551  KX007210303370934        7  20210303
# 1         KX007  2021030365922951  KX007210303371080        7  20210303
# 2         KX007  2021030365924361  KX007210303371081        7  20210303
# 3         KX007  2021030365928921  KX007210303371205        7  20210303
# 4         KX007  2021030365930451  KX007210303370967        7  20210303
# ...         ...               ...                ...      ...       ...
# 1786369   GP001      201806270001  GP001210628546912        7  20210628
# 1786370   GP001      201806270001  GP001210628546912        7  20210628
# 1786371   GP001      201806270001  GP001210628546912        7  20210628
# 1786372   GP001      201806270001  GP001210628546912        7  20210628
# 1786373   GP001      201806270001  GP001210628546912        7  20210628
#
#          BKG_TIME   SHPR_CD  INV_AMT  ITEM_SEQ        ITEM_CD  ...  \
# ...

# %%
A = pd.concat([FC_order,Distance,Trafic], axis=1)
with open("FC_NEW.pickle","wb") as fw:
    pickle.dump(A, fw)
A
# Out:
#         CORP_ID        REF_ORD_NO             BKG_NO  BKG_TYP  BKG_DATE  \
# 0         KX007  2021030365922551  KX007210303370934        7  20210303
# 1         KX007  2021030365922951  KX007210303371080        7  20210303
# 2         KX007  2021030365924361  KX007210303371081        7  20210303
# 3         KX007  2021030365928921  KX007210303371205        7  20210303
# 4         KX007  2021030365930451  KX007210303370967        7  20210303
# ...         ...               ...                ...      ...       ...
# 1786369   GP001      201806270001  GP001210628546912        7  20210628
# 1786370   GP001      201806270001  GP001210628546912        7  20210628
# 1786371   GP001      201806270001  GP001210628546912        7  20210628
# 1786372   GP001      201806270001  GP001210628546912        7  20210628
# 1786373   GP001      201806270001  GP001210628546912        7  20210628
#
#          BKG_TIME   SHPR_CD  INV_AMT  ITEM_SEQ        ITEM_CD  ...  \
# ...

# %%
A.to_csv("/Users/heogeonhyeock/Desktop/인빅_프로젝트/FC주문/FC_NEW.csv")
