# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
import pickle
import os
import geocoder
import matplotlib.pyplot as plt

# %% [markdown]
# ## 파일 불러오기

# %%
with open("/Users/heogeonhyeock/Desktop/인빅_프로젝트/FC주문/FC_order.pickle","rb") as fr:
    Distance = pickle.load(fr).reset_index(drop=True)
Distance

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ## Null값 제거 & CORP_ID = 곤지암 hub

# %%
Distance = Distance[Distance["CORP_ID"] == "KX007"].dropna(axis=0)

# %% [markdown]
# ## 5개 미만의 데이터 즉 노이즈 제거

# %%
Df_list = ["SHPR_ADDR_1","SHPR_ADDR_2","CNEE_ADDR_1","CNEE_ADDR_2"]
Df_list2 = ["SHPR_ADDR_2","CNEE_ADDR_2"]
Distance = Distance[Df_list]

Df_index = []
for i in Df_list2:
    for j in list(Distance[i].unique()):
        if len(Distance[Distance[i] == j]) < 5:
            Df_index.append(Distance[Distance[i] == j].index)
            
for i in Df_index:
    Distance = Distance.drop(index = i)
Distance

# %% [markdown]
# ## New Collum 송화인과 수화인 생성

# %%
Distance["송화인"] = Distance["SHPR_ADDR_1"] + " " + Distance["SHPR_ADDR_2"]
Distance["수화인"] = Distance["CNEE_ADDR_1"] + " " + Distance["CNEE_ADDR_2"]
Distance = Distance.drop(Df_list, axis = 1).reset_index(drop=False)
Distance

# %% [markdown]
# # geocoder를 이용한 거리계산

# %% [markdown]
# ## 거리계산 결과 Dict 생성
#     A = set(Distance["송화인"].unique())
#     B = set(Distance["수화인"].unique())
#     A < B => True
#     (즉 송화인의 고유값 집합이 수화인의 고유값 집합에 포함됨)

# %%
A = list(Distance["수화인"].unique())
Distance_Dict = {}
KX007_loc = geocoder.location("경기도 광주시 도척면 진우리 1006") # 곤지암 Hub 위치

for i in A:
    try:
        Distance_Dict[i] = geocoder.distance(geocoder.location(i),KX007_loc)
    except:
        Distance_Dict[i] = None

for i,j in Distance_Dict.items():
    if j == 0:
        Distance_Dict[i] = None

# %% [markdown]
# ## 거리계산 결과 저장

# %%
with open("Distance_Dict2.pickle","wb") as fw:
    pickle.dump(Distance_Dict, fw)

# %% [markdown]
# ## 거리계산 결과 불러오기

# %%
with open("/Users/heogeonhyeock/Desktop/인빅_프로젝트/Distance_Dict2.pickle","rb") as fr:
    Distance_Dict = pickle.load(fr)

# %% [markdown]
# # 데이터프레임 생성

# %% [markdown]
# ## 파일 불러오기

# %%
with open("/Users/heogeonhyeock/Desktop/인빅_프로젝트/FC주문/FC_order.pickle","rb") as fr:
    Distance = pickle.load(fr).reset_index(drop=True)

# %% [markdown]
# ## 데이터 전처리
#     2 데이터 전처리와 동일한 방식

# %%
# Null값 제거 & CORP_ID = 곤지암 hub
Distance = Distance[Distance["CORP_ID"] == "KX007"].dropna(axis=0)

# 5개 미만의 데이터 즉 노이즈 제거
Df_list2 = ["SHPR_ADDR_2","CNEE_ADDR_2"]
Df_index = []
for i in Df_list2:
    for j in list(Distance[i].unique()):
        if len(Distance[Distance[i] == j]) < 5:
            Df_index.append(Distance[Distance[i] == j].index)
            
for i in Df_index:
    Distance = Distance.drop(index = i)
Distance
# Out:
#         CORP_ID          REF_ORD_NO             BKG_NO  BKG_TYP  BKG_DATE  \
# 1         KX007    2021030365922951  KX007210303371080        7  20210303
# 2         KX007    2021030365924361  KX007210303371081        7  20210303
# 3         KX007    2021030365928921  KX007210303371205        7  20210303
# 4         KX007    2021030365930451  KX007210303370967        7  20210303
# 5         KX007    2021030365930451  KX007210303370967        7  20210303
# ...         ...                 ...                ...      ...       ...
# 1786343   KX007    2021063075245201  KX007210702671565        7  20210630
# 1786347   KX007    2021062954478421  KX007210702674788        7  20210629
# 1786348   KX007    2021063067849541  KX007210703706457        7  20210630
# 1786349   KX007  2021063078029521_1  KX007210704717899        7  20210630
# 1786354   KX007    2021062966256441  KX007210703687487        7  20210629
#
#          BKG_TIME   SHPR_CD   INV_AMT  ITEM_SEQ        ITEM_CD  ...  \
# 1           35521  90001441   20900.0         1   4610261043_2  ...
# 2           35513  90001441   37900.0         1   4936599538_1  ...
# 3           35608  90001542   69800.0         1   3858391637_1  ...
# 4           35551  90001341   73700.0         1     4631307460  ...
# 5           35551  90001341   73700.0         2     2475138283  ...
# ...           ...       ...       ...       ...            ...  ...
# 1786343    122001  90001622  125800.0         1  5519470982_18  ...
# 1786347    122812  90001443   16900.0         1  5002901762_12  ...
# 1786348       256  90001662  138000.0         1     5410093340  ...
# 1786349    143118  90001443   13900.0         1     5582399098  ...
# 1786354    223503  90001622  125800.0         1     5525868431  ...
#
#         DLVSUBCLSFCD     INS_ID  INS_DATE INS_TIME  POST_ZONE  SPLIT_EXEC_YN  \
# 1                  4  iNEXBatch  20210303   131425       50.0              N
# 2                  0  iNEXBatch  20210303   131425       53.0              N
# 3                  1  iNEXBatch  20210303   131425        6.0              N
# 4                  1  iNEXBatch  20210303   131425       10.0              N
# 5                  1  iNEXBatch  20210303   131425       10.0              N
# ...              ...        ...       ...      ...        ...            ...
# 1786343            8  iNEXBatch  20210702   101425        7.0              N
# 1786347            1  iNEXBatch  20210702   122203       16.0              N
# 1786348            3  iNEXBatch  20210703   220152       63.0              N
# 1786349           1m      BATCH  20210704    55047       34.0              N
# 1786354           2j  iNEXBatch  20210703     1424       48.0              N
#
#         SHPR_ADDR_1 SHPR_ADDR_2 CNEE_ADDR_1 CNEE_ADDR_2
# 1               경기도         광주시        경상남도         김해시
# 2               경기도         광주시        경상남도         거제시
# 3               경기도         광주시       서울특별시         서초구
# 4               경기도         광주시         경기도         김포시
# 5               경기도         광주시         경기도         김포시
# ...             ...         ...         ...         ...
# 1786343         경기도         광주시       서울특별시         동작구
# 1786347         경기도         광주시         경기도         수원시
# 1786348         경기도         광주시     제주특별자치도         제주시
# 1786349         경기도         광주시       대전광역시         유성구
# 1786354         경기도         광주시       부산광역시        해운대구
#
# [1496444 rows x 32 columns]

# %% [markdown]
# ## 거리 정보열 생성

# %%
Distance["distance_송화"] = None
Distance["distance_수화"] = None
Distance["distance"] = None
Distance
# Out:
#         CORP_ID          REF_ORD_NO             BKG_NO  BKG_TYP  BKG_DATE  \
# 1         KX007    2021030365922951  KX007210303371080        7  20210303
# 2         KX007    2021030365924361  KX007210303371081        7  20210303
# 3         KX007    2021030365928921  KX007210303371205        7  20210303
# 4         KX007    2021030365930451  KX007210303370967        7  20210303
# 5         KX007    2021030365930451  KX007210303370967        7  20210303
# ...         ...                 ...                ...      ...       ...
# 1786343   KX007    2021063075245201  KX007210702671565        7  20210630
# 1786347   KX007    2021062954478421  KX007210702674788        7  20210629
# 1786348   KX007    2021063067849541  KX007210703706457        7  20210630
# 1786349   KX007  2021063078029521_1  KX007210704717899        7  20210630
# 1786354   KX007    2021062966256441  KX007210703687487        7  20210629
#
#          BKG_TIME   SHPR_CD   INV_AMT  ITEM_SEQ        ITEM_CD  ... INS_TIME  \
# 1           35521  90001441   20900.0         1   4610261043_2  ...   131425
# 2           35513  90001441   37900.0         1   4936599538_1  ...   131425
# 3           35608  90001542   69800.0         1   3858391637_1  ...   131425
# 4           35551  90001341   73700.0         1     4631307460  ...   131425
# 5           35551  90001341   73700.0         2     2475138283  ...   131425
# ...           ...       ...       ...       ...            ...  ...      ...
# 1786343    122001  90001622  125800.0         1  5519470982_18  ...   101425
# 1786347    122812  90001443   16900.0         1  5002901762_12  ...   122203
# 1786348       256  90001662  138000.0         1     5410093340  ...   220152
# 1786349    143118  90001443   13900.0         1     5582399098  ...    55047
# 1786354    223503  90001622  125800.0         1     5525868431  ...     1424
#
#          POST_ZONE  SPLIT_EXEC_YN SHPR_ADDR_1  SHPR_ADDR_2  CNEE_ADDR_1  \
# 1             50.0              N         경기도          광주시         경상남도
# 2             53.0              N         경기도          광주시         경상남도
# 3              6.0              N         경기도          광주시        서울특별시
# 4             10.0              N         경기도          광주시          경기도
# 5             10.0              N         경기도          광주시          경기도
# ...            ...            ...         ...          ...          ...
# 1786343        7.0              N         경기도          광주시        서울특별시
# 1786347       16.0              N         경기도          광주시          경기도
# 1786348       63.0              N         경기도          광주시      제주특별자치도
# 1786349       34.0              N         경기도          광주시        대전광역시
# 1786354       48.0              N         경기도          광주시        부산광역시
#
#         CNEE_ADDR_2 distance_송화 distance_수화 distance
# 1               김해시        None        None     None
# 2               거제시        None        None     None
# 3               서초구        None        None     None
# 4               김포시        None        None     None
# 5               김포시        None        None     None
# ...             ...         ...         ...      ...
# 1786343         동작구        None        None     None
# 1786347         수원시        None        None     None
# 1786348         제주시        None        None     None
# 1786349         유성구        None        None     None
# 1786354        해운대구        None        None     None
#
# [1496444 rows x 35 columns]

# %% [markdown]
# ## 계산결과 적용

# %%
for i in list(Distance.index):
    try:
        Distance["distance_송화"][i] = Distance_Dict[(Distance["SHPR_ADDR_1"][i] + " " + Distance["SHPR_ADDR_2"][i])]
    except:
        print("{}번째 인덱스에서 오류".format(i))       
    try:
        Distance["distance_수화"][i] = Distance_Dict[Distance["CNEE_ADDR_1"][i] + " " + Distance["CNEE_ADDR_2"][i]]
    except:
        print("{}번째 인덱스에서 오류".format(i))

Distance["distance"] = Distance["distance_송화"] + Distance["distance_수화"]
Distance
# Out:
# <ipython-input-15-ea3a4c8b4488>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Distance["distance_송화"][i] = Distance_Dict[(Distance["SHPR_ADDR_1"][i] + " " + Distance["SHPR_ADDR_2"][i])]
# <ipython-input-15-ea3a4c8b4488>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Distance["distance_수화"][i] = Distance_Dict[Distance["CNEE_ADDR_1"][i] + " " + Distance["CNEE_ADDR_2"][i]]
#         CORP_ID          REF_ORD_NO             BKG_NO  BKG_TYP  BKG_DATE  \
# 1         KX007    2021030365922951  KX007210303371080        7  20210303
# 2         KX007    2021030365924361  KX007210303371081        7  20210303
# 3         KX007    2021030365928921  KX007210303371205        7  20210303
# 4         KX007    2021030365930451  KX007210303370967        7  20210303
# 5         KX007    2021030365930451  KX007210303370967        7  20210303
# ...         ...                 ...                ...      ...       ...
# 1786343   KX007    2021063075245201  KX007210702671565        7  20210630
# 1786347   KX007    2021062954478421  KX007210702674788        7  20210629
# 1786348   KX007    2021063067849541  KX007210703706457        7  20210630
# 1786349   KX007  2021063078029521_1  KX007210704717899        7  20210630
# 1786354   KX007    2021062966256441  KX007210703687487        7  20210629
#
#          BKG_TIME   SHPR_CD   INV_AMT  ITEM_SEQ        ITEM_CD  ... INS_TIME  \
# 1           35521  90001441   20900.0         1   4610261043_2  ...   131425
# 2           35513  90001441   37900.0         1   4936599538_1  ...   131425
# 3           35608  90001542   69800.0         1   3858391637_1  ...   131425
# 4           35551  90001341   73700.0         1     4631307460  ...   131425
# 5           35551  90001341   73700.0         2     2475138283  ...   131425
# ...           ...       ...       ...       ...            ...  ...      ...
# 1786343    122001  90001622  125800.0         1  5519470982_18  ...   101425
# 1786347    122812  90001443   16900.0         1  5002901762_12  ...   122203
# 1786348       256  90001662  138000.0         1     5410093340  ...   220152
# 1786349    143118  90001443   13900.0         1     5582399098  ...    55047
# 1786354    223503  90001622  125800.0         1     5525868431  ...     1424
#
#          POST_ZONE  SPLIT_EXEC_YN SHPR_ADDR_1  SHPR_ADDR_2  CNEE_ADDR_1  \
# 1             50.0              N         경기도          광주시         경상남도
# 2             53.0              N         경기도          광주시         경상남도
# 3              6.0              N         경기도          광주시        서울특별시
# 4             10.0              N         경기도          광주시          경기도
# 5             10.0              N         경기도          광주시          경기도
# ...            ...            ...         ...          ...          ...
# 1786343        7.0              N         경기도          광주시        서울특별시
# 1786347       16.0              N         경기도          광주시          경기도
# 1786348       63.0              N         경기도          광주시      제주특별자치도
# 1786349       34.0              N         경기도          광주시        대전광역시
# 1786354       48.0              N         경기도          광주시        부산광역시
#
#         CNEE_ADDR_2 distance_송화 distance_수화 distance
# 1               김해시     14.3362     270.613     None
# 2               거제시     14.3362     294.613     None
# 3               서초구     14.3362      32.841     None
# 4               김포시     14.3362     64.2811     None
# 5               김포시     14.3362     64.2811     None
# ...             ...         ...         ...      ...
# 1786343         동작구     14.3362     41.4585     None
# 1786347         수원시     14.3362     28.4156     None
# 1786348         제주시     14.3362     432.125     None
# 1786349         유성구     14.3362     106.525     None
# 1786354        해운대구     14.3362     290.217     None
#
# [1496444 rows x 35 columns]

# %%
Distance
# Out:
#         CORP_ID          REF_ORD_NO             BKG_NO  BKG_TYP  BKG_DATE  \
# 1         KX007    2021030365922951  KX007210303371080        7  20210303
# 2         KX007    2021030365924361  KX007210303371081        7  20210303
# 3         KX007    2021030365928921  KX007210303371205        7  20210303
# 4         KX007    2021030365930451  KX007210303370967        7  20210303
# 5         KX007    2021030365930451  KX007210303370967        7  20210303
# ...         ...                 ...                ...      ...       ...
# 1786343   KX007    2021063075245201  KX007210702671565        7  20210630
# 1786347   KX007    2021062954478421  KX007210702674788        7  20210629
# 1786348   KX007    2021063067849541  KX007210703706457        7  20210630
# 1786349   KX007  2021063078029521_1  KX007210704717899        7  20210630
# 1786354   KX007    2021062966256441  KX007210703687487        7  20210629
#
#          BKG_TIME   SHPR_CD   INV_AMT  ITEM_SEQ        ITEM_CD  ... INS_TIME  \
# 1           35521  90001441   20900.0         1   4610261043_2  ...   131425
# 2           35513  90001441   37900.0         1   4936599538_1  ...   131425
# 3           35608  90001542   69800.0         1   3858391637_1  ...   131425
# 4           35551  90001341   73700.0         1     4631307460  ...   131425
# 5           35551  90001341   73700.0         2     2475138283  ...   131425
# ...           ...       ...       ...       ...            ...  ...      ...
# 1786343    122001  90001622  125800.0         1  5519470982_18  ...   101425
# 1786347    122812  90001443   16900.0         1  5002901762_12  ...   122203
# 1786348       256  90001662  138000.0         1     5410093340  ...   220152
# 1786349    143118  90001443   13900.0         1     5582399098  ...    55047
# 1786354    223503  90001622  125800.0         1     5525868431  ...     1424
#
#          POST_ZONE  SPLIT_EXEC_YN SHPR_ADDR_1  SHPR_ADDR_2  CNEE_ADDR_1  \
# 1             50.0              N         경기도          광주시         경상남도
# 2             53.0              N         경기도          광주시         경상남도
# 3              6.0              N         경기도          광주시        서울특별시
# 4             10.0              N         경기도          광주시          경기도
# 5             10.0              N         경기도          광주시          경기도
# ...            ...            ...         ...          ...          ...
# 1786343        7.0              N         경기도          광주시        서울특별시
# 1786347       16.0              N         경기도          광주시          경기도
# 1786348       63.0              N         경기도          광주시      제주특별자치도
# 1786349       34.0              N         경기도          광주시        대전광역시
# 1786354       48.0              N         경기도          광주시        부산광역시
#
#         CNEE_ADDR_2 distance_송화 distance_수화 distance
# 1               김해시     14.3362     270.613  284.949
# 2               거제시     14.3362     294.613  308.949
# 3               서초구     14.3362      32.841  47.1772
# 4               김포시     14.3362     64.2811  78.6173
# 5               김포시     14.3362     64.2811  78.6173
# ...             ...         ...         ...      ...
# 1786343         동작구     14.3362     41.4585  55.7948
# 1786347         수원시     14.3362     28.4156  42.7518
# 1786348         제주시     14.3362     432.125  446.461
# 1786349         유성구     14.3362     106.525  120.861
# 1786354        해운대구     14.3362     290.217  304.554
#
# [1496444 rows x 35 columns]

# %% [markdown]
# ## 데이터 저장

# %%
with open("FC_order_distance2.pickle","wb") as fw:
    pickle.dump(Distance, fw)

# %% [markdown]
# ## 저장된 New FC_order 불러오기

# %%
# Na값 제거, 주소지 중 빈도수가 5 미만인 행 삭제
with open("/Users/heogeonhyeock/Desktop/인빅_프로젝트/FC_order_distance2.pickle","rb") as fr:
    FC_order = pickle.load(fr).reset_index(drop=True)
FC_order

# %% [markdown]
# # 거리별 데이터 시각화

# %% [markdown]
# ## 데이터 가공

# %%
FC_order_distance = np.array(FC_order["distance"]) 
IQR = np.quantile(FC_order_distance,0.75) - np.quantile(FC_order_distance,0.25)
IQR_max = np.quantile(FC_order_distance,0.75) + 1.5 * IQR
FC_plot = FC_order_distance[FC_order_distance < IQR_max] # outlier 갯수 : 9075(np.sum(FC_order_distance >= IQR_max))

# %% [markdown]
# ## 데이터 분포

# %%
plot_x = np.linspace(0,np.max(FC_plot),101) # 구간을 100등분
Y,X = np.histogram(FC_plot,plot_x)
plt.plot(X[1:],Y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
